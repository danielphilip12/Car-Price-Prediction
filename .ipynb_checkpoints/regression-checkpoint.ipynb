# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
warnings.filterwarnings("ignore")
plt.rcParams['figure.figsize'] = (10, 6)
sns.set_style('darkgrid')
pd.options.display.float_format = '{:,.2f}'.format

# %%
df = pd.read_csv('./data/cleaned_car_prices_under_mill.csv')

# %%
df.head()
# Out:
#             car_name  yr_mfr fuel_type  kms_run  sale_price   city  \
# 0       maruti swift    2015    petrol     8063      386399  noida
# 1    maruti alto 800    2016    petrol    23104      265499  noida
# 2  hyundai grand i10    2017    petrol    23402      477699  noida
# 3       maruti swift    2013    diesel    39124      307999  noida
# 4  hyundai grand i10    2015    petrol    22116      361499  noida
#
#    times_viewed  body_type transmission          variant  assured_buy  \
# 0         18715  hatchback       manual          lxi opt         True
# 1          2676  hatchback       manual              lxi         True
# 2           609  hatchback       manual  sports 1.2 vtvt         True
# 3          6511  hatchback       manual              vdi         True
# 4          3225  hatchback       manual   magna 1.2 vtvt        False
#
#   registered_city registered_state  is_hot   rto         source     make  \
# ...

# %%
df['sale_price'].describe()
# Out:
# count     6,866.00
# mean    414,170.98
# std     185,447.22
# min      20,000.00
# 25%     278,824.00
# 50%     374,299.00
# 75%     514,349.00
# max     999,199.00
# Name: sale_price, dtype: float64

# %%
# sns.heatmap(df.corr(numeric_only=True)[['sale_price']],
#            vmin=-1,
#            vmax=1,
#            annot=True, 
#            cmap='coolwarm')

# %%
df.shape
# Out:
# (6866, 33)

# %%
num_columns = ['yr_mfr', 'total_owners', 'kms_run']
obj_columns = ['transmission', 'make', 'model', 'body_type', 'source', 'fuel_type', 'car_availability', 'city', 'variant'] 
misc_columns = ['car_rating_codes', 'transmission_missing', 'car_availability_missing']

# %%
X = df[num_columns+obj_columns+misc_columns]
y = df['sale_price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# X = pd.get_dummies(X, columns=nominal_columns)

# %% [markdown]
# ### Help Functions

# %%
def show_error_differences(y_test, y_preds):
    errors = abs(y_test - y_preds)

    min_val = min(y_test.min(), y_preds.min())
    max_val = max(y_test.max(), y_preds.max())

    plt.figure(figsize=(7, 7))
    sns.scatterplot(
        x=y_test,
        y=y_preds,
        hue=errors,
        palette="coolwarm",
        legend=True
    )
    
    plt.plot([min_val, max_val], [min_val, max_val], 'k--')
    plt.xlabel("Actual Prices")
    plt.ylabel("Predicted Prices")
    plt.title("Actual vs Predicted Prices (Colored by Error)")
    plt.show()

# %%
def pipeline_creator(model, scaler=StandardScaler()):
    transformers = [
        ("cat", OneHotEncoder(handle_unknown="ignore"), obj_columns),
        ("scale", scaler, num_columns),
        ('no_scale', 'passthrough', misc_columns)
    ]

    preprocessor = ColumnTransformer(
        transformers=transformers,
        remainder="drop"  
    )
    _model = Pipeline(
        steps=[
            ("preprocess", preprocessor),
            ("regressor", model)
        ]
    )

    return _model

# %% [markdown]
# ### Baseline

# %%
baseline = np.full_like(y_test, y_test.mean())

# %%
root_mean_squared_error(y_test, baseline)
# Out:
# 185512.62556472662

# %% [markdown]
# ### Linear Regression

# %%
lr_model = pipeline_creator(LinearRegression())

# %%
lr_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['transmission', 'make',
#                                                    'model', 'body_type',
#                                                    'source', 'fuel_type',
#                                                    'car_availability', 'city',
#                                                    'variant']),
#                                                  ('scale', StandardScaler(),
#                                                   ['yr_mfr', 'total_owners',
#                                                    'kms_run']),
#                                                  ('no_scale', 'passthrough',
#                                                   ['car_rating_codes',
# ...

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.9132507231456566

# %%
y_preds = lr_model.predict(X_test)

# %%
root_mean_squared_error(y_test, y_preds)
# Out:
# 54639.460636491414

# %%
show_error_differences(y_test, y_preds)

# %% [markdown]
# ## Pickling

# %%
import pickle

# %%
with open('linreg.pkl', 'wb') as file:
    pickle.dump(lr_model, file)

# %% [markdown]
# ## KNN Regression

# %%
# preprocessor = ColumnTransformer(
#     transformers=[
#         ("cat", OneHotEncoder(handle_unknown="ignore"), nominal_columns),
#         ("scale", StandardScaler(), columns_to_scale)
#     ],
#     remainder='passthrough'
# )

# %%
# model = Pipeline(
#     steps=[
#         ("preprocess", preprocessor),
#         ("knn", KNeighborsRegressor())
#     ]
# )

# %%
knn_model = pipeline_creator(KNeighborsRegressor())

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
param_grid = {
    "regressor__n_neighbors": np.arange(3, 31, 2),
    "regressor__weights": ["uniform", "distance"],
    "regressor__metric": ["euclidean", "manhattan", "minkowski"],
    "preprocess__scale": [StandardScaler(), MinMaxScaler()]
}

# %%
grid = GridSearchCV(knn_model,
                   param_grid=param_grid,
                   cv=kfold)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['transmission',
#                                                                           'make',
#                                                                           'model',
#                                                                           'body_type',
#                                                                           'source',
#                                                                           'fuel_type',
#                                                                           'car_availability',
# ...

# %%
grid.score(X_test, y_test)
# Out:
# 0.8668528335122935

# %%
y_preds = grid.predict(X_test)

# %%
root_mean_squared_error(y_test, y_preds)
# Out:
# 67692.32585333333

# %%
# with open('knnreg.pkl', 'wb') as file:
#     pickle.dump(grid.best_estimator_, file)

# %%
show_error_differences(y_test, y_preds)

# %%
grid.best_params_
# Out:
# {'preprocess__scale': StandardScaler(),
#  'regressor__metric': 'manhattan',
#  'regressor__n_neighbors': np.int64(5),
#  'regressor__weights': 'distance'}

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# preprocessor = ColumnTransformer(
#     transformers=[
#         ("cat", OneHotEncoder(handle_unknown="ignore"), nominal_columns),
#         ("scale", StandardScaler(), columns_to_scale)
#     ],
#     remainder='passthrough'
# )

# %%
# model = Pipeline(
#     steps=[
#         ("preprocess", preprocessor),
#         ("rf", RandomForestRegressor())
#     ]
# )

# %%
param_grid = {
    'regressor__max_depth': [10, 20, None],
    'preprocess__scale': [StandardScaler(), MinMaxScaler()]
}

# %%
rf_model = pipeline_creator(RandomForestRegressor(random_state=42), StandardScaler())

# %%
grid_rf = GridSearchCV(rf_model, param_grid, cv=3)

# %%
grid_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['transmission',
#                                                                           'make',
#                                                                           'model',
#                                                                           'body_type',
#                                                                           'source',
#                                                                           'fuel_type',
#                                                                           'car_availability',
#                                                                           'city',
# ...

# %%
grid_rf.score(X_test, y_test)
# Out:
# 0.9186646935673769

# %%
grid_rf.best_params_
# Out:
# {'preprocess__scale': StandardScaler(), 'regressor__max_depth': None}

# %%
y_preds = grid_rf.predict(X_test)

# %%
root_mean_squared_error(y_test, y_preds)
# Out:
# 52906.98651959735

# %%
with open('rf.pkl', 'wb') as file:
    pickle.dump(grid_rf.best_estimator_, file)

# %%
# plt.figure(figsize=(7, 7))
# sns.scatterplot(x=y_test, y=y_preds, alpha=0.6)

# min_val = min(y_test.min(), y_preds.min())
# max_val = max(y_test.max(), y_preds.max())

# plt.plot([min_val, max_val], [min_val, max_val], 'r--')

# plt.xlabel("Actual Prices")
# plt.ylabel("Predicted Prices")
# plt.title("Actual vs Predicted Prices")
# plt.show()

# %%
# errors = abs(y_test - y_preds)

# plt.figure(figsize=(7, 7))
# sns.scatterplot(
#     x=y_test,
#     y=y_preds,
#     hue=errors,
#     palette="coolwarm",
#     legend=True
# )

# plt.plot([min_val, max_val], [min_val, max_val], 'k--')
# plt.xlabel("Actual Prices")
# plt.ylabel("Predicted Prices")
# plt.title("Actual vs Predicted Prices (Colored by Error)")
# plt.show()

# %%
show_error_differences(y_test, y_preds)
